# %%
string = """> welcome to a quote block
>thus we are doing the testing here
> in
>
>the jupyter notebooks, seems to be the best way for quick testing!!
>woop,woop!
"""

split = string.splitlines()
new_lines = []
for line in split:
    new = line[1:].strip()
    new_lines.append(new)
print(new_lines)
# Out:
# ['welcome to a quote block', 'thus we are doing the testing here', 'in', '', 'the jupyter notebooks, seems to be the best way for quick testing!!', 'woop,woop!']
